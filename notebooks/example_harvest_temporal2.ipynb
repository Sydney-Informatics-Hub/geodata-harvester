# %% [markdown]
# GEODATA-HARVESTER NOTEBOOK: Temporal Processing Example II
# ----------------------------------------------------------
#
# This notebook demonstrates the temporal processing capabilities of the Geodata-Harvester for extracting a time series (using four time intervals) of climate and satellite data with multiple bands.
# The example is based on the settings as defined in the `settings/settings_temporal2.yaml` file.
# Only data sources with a time component are selected, i.e., SILO, DEA, and Google Earth Engine (GEE) satellite data.
#
#
# The Geodata-Harvester enables researchers with reusable workflows for automatic data extraction from a range of data sources including spatial-temporal processing into useable formats. User provided data is auto-completed with a suitable set of spatial- and temporal-aligned covariates as a ready-made dataset for machine learning and agriculture models. In addition, all requested data layer maps are automatically extracted and aligned for a specific region and time period.
#
# The main workflow of the Harvester is as follows:
#
# Options and user settings (e.g., data layer selections, spatial coverage, temporal constraints, i/o directory names) are defined by the user in the notebook settings menu or can be loaded with a settings yaml file (e.g., settings/settings_test). All settings are also saved in a yaml file for reusability.
#
# The notebook imports settings and all Python modules that include functionality to download and extract data for each data source. After settings are read in, checked, and processed into valid data retrieval (API) queries, all selected data layers are sequentially downloaded and then processed into a clean dataframe table and co-registered raster maps. The entire workflow can be run either completely automatically or individually by selecting only certain process parts in the Notebook.
# Additional data sources can be best added by writing the API handlers and extraction functionalities as separate Python module, which are then imported by the Notebook. Currently the following data sources are supported by the following modules:
#
# - 'getdata_slga.py': Soil Data from Soil and Landscape Grid of Australia (SLGA)
# - 'getdata_landscape': Landscape data from Soil and Landscape Grid of Australia (SLGA)
# - 'getdata_silo.py': Climate Data from SILO
# - 'getdata_dem.py: 'National Digital Elevation Model (DEM) 1 Second plus Slope and Apect calculation
# - 'getdata_dea_nci.py: 'Digital Earth Australia's (DEA) Geoscience Earth Observations via NCI server
# - 'getdata_dea.py: 'Digital Earth Australia's (DEA) Geoscience Earth Observations via Open Web Service server provided by DEA
# - 'getdata_radiometric.py': Geoscience Australia National Geophysical Compilation Sub-collection Radiometrics
# 'eeharvest': Google Earth Engine API integration handler
# For more details. please see README and the Data Overview page.
#
# This notebook is part of the Data Harvester project developed for the Agricultural Research Federation (AgReFed).
#
# Copyright 2023 Sydney Informatics Hub (SIH), The University of Sydney

# %% [markdown]
# ### Import libraries

# %%
import os

# Import harvest function from geodata_harvester
from geodata_harvester import harvest

# %% [markdown]
# ### Specify settings file
#
# Set settings in settings YAML file beforehand, such as data-layer names, region, and dates.

# %%
# Path to file:
path_settings = 'settings'
# Filename
fname_settings = 'settings_temporal2.yaml'
infname = os.path.join(path_settings,fname_settings)

# %% [markdown]
# ### Harvest
#
# The harvest function executes automatically all download and processing steps for all data layers from the web as specified in settings file above.
# Filenames of the processed files and some metadata is saved in a dataframe df.

# %%
df = harvest.run(infname, return_df = True)
# Out:
# Starting the data harvester -----
# ℹ Found the following 3 sources: ['DEA', 'SILO', 'GEE']
#
# Downloading from API sources -----
# ⊙ Initialising Earth Engine... 4.0s
# ✔ Done
#
# ⌛ Downloading Google Earth Engine data...
# ℹ Multiple collections detected in Google Earth Engine config file
# ℹ Validating settings and generating 2 configuration profiles
#   Profile 1 will process 'LANDSAT/LC09/C02/T1_L2' and download bands ['SR_B2', 'SR_B3', 'SR_B4']
#   Profile 2 will process 'COPERNICUS/S2_SR_HARMONIZED' and download bands ['NDVI']
# ℹ -------------------- Downloading Profile 1 --------------------
# Running preprocess() -----
# ℹ Number of image(s) found: 1
# ⊙ Applying scale, offset and cloud masks... 1.6s
# ⊙ Calculating spectral indices: NDVI... 1.4s
# ✔ Preprocessing complete
# Running download() -----
# ℹ Band(s) selected: ['SR_B2_mean', 'SR_B3_mean', 'SR_B4_mean']
# ℹ Setting scale to ~160.2m, converted from 6.0 arcsec at latitude -30.27
# ℹ Setting download dir to test_temporal/ee
# ⊙ Downloading ee_LANDSAT_2a2b9af2.tif 4.6s
# ✔ Google Earth Engine download(s) complete
# ℹ -------------------- Downloading Profile 2 --------------------
# Running preprocess() -----
# ℹ Number of image(s) found: 22
# ⊙ Applying scale, offset and cloud masks... 1.5s
# ⊙ Calculating spectral indices: NDVI... 0.9s
# ✔ Preprocessing complete
# Running download() -----
# ℹ Band(s) selected: ['NDVI_mean']
# ℹ Setting scale to ~160.2m, converted from 6.0 arcsec at latitude -30.27
# ℹ Setting download dir to test_temporal/ee
# ⊙ Downloading ee_COPERNICUS_d1229d42.tif 4.6s
# ✔ Google Earth Engine download(s) complete
# ℹ Multiple collections detected in Google Earth Engine config file
# ℹ Validating settings and generating 2 configuration profiles
#   Profile 1 will process 'LANDSAT/LC09/C02/T1_L2' and download bands ['SR_B2', 'SR_B3', 'SR_B4']
#   Profile 2 will process 'COPERNICUS/S2_SR_HARMONIZED' and download bands ['NDVI']
# ℹ -------------------- Downloading Profile 1 --------------------
# Running preprocess() -----
# ℹ Number of image(s) found: 1
# ⊙ Applying scale, offset and cloud masks... 1.4s
# ⊙ Calculating spectral indices: NDVI... 0.7s
# ✔ Preprocessing complete
# Running download() -----
# ℹ Band(s) selected: ['SR_B2_mean', 'SR_B3_mean', 'SR_B4_mean']
# ℹ Setting scale to ~160.2m, converted from 6.0 arcsec at latitude -30.27
# ℹ Setting download dir to test_temporal/ee
# ⊙ Downloading ee_LANDSAT_71cd5d63.tif 4.5s
# ✔ Google Earth Engine download(s) complete
# ℹ -------------------- Downloading Profile 2 --------------------
# Running preprocess() -----
# ℹ Number of image(s) found: 24
# ⊙ Applying scale, offset and cloud masks... 1.6s
# ⊙ Calculating spectral indices: NDVI... 0.4s
# ✔ Preprocessing complete
# Running download() -----
# ℹ Band(s) selected: ['NDVI_mean']
# ℹ Setting scale to ~160.2m, converted from 6.0 arcsec at latitude -30.27
# ℹ Setting download dir to test_temporal/ee
# ⊙ Downloading ee_COPERNICUS_fcb50880.tif 4.5s
# ✔ Google Earth Engine download(s) complete
# ℹ Multiple collections detected in Google Earth Engine config file
# ℹ Validating settings and generating 2 configuration profiles
#   Profile 1 will process 'LANDSAT/LC09/C02/T1_L2' and download bands ['SR_B2', 'SR_B3', 'SR_B4']
#   Profile 2 will process 'COPERNICUS/S2_SR_HARMONIZED' and download bands ['NDVI']
# ℹ -------------------- Downloading Profile 1 --------------------
# Running preprocess() -----
# ℹ Number of image(s) found: 1
# ⊙ Applying scale, offset and cloud masks... 1.5s
# ⊙ Calculating spectral indices: NDVI... 0.8s
# ✔ Preprocessing complete
# Running download() -----
# ℹ Band(s) selected: ['SR_B2_mean', 'SR_B3_mean', 'SR_B4_mean']
# ℹ Setting scale to ~160.2m, converted from 6.0 arcsec at latitude -30.27
# ℹ Setting download dir to test_temporal/ee
# ⊙ Downloading ee_LANDSAT_6b57e1a5.tif 4.6s
# ✔ Google Earth Engine download(s) complete
# ℹ -------------------- Downloading Profile 2 --------------------
# Running preprocess() -----
# ℹ Number of image(s) found: 24
# ⊙ Applying scale, offset and cloud masks... 1.5s
# ⊙ Calculating spectral indices: NDVI... 0.9s
# ✔ Preprocessing complete
# Running download() -----
# ℹ Band(s) selected: ['NDVI_mean']
# ℹ Setting scale to ~160.2m, converted from 6.0 arcsec at latitude -30.27
# ℹ Setting download dir to test_temporal/ee
# ⊙ Downloading ee_COPERNICUS_03b3ab57.tif 4.1s
# ✔ Google Earth Engine download(s) complete
# ℹ Multiple collections detected in Google Earth Engine config file
# ℹ Validating settings and generating 2 configuration profiles
#   Profile 1 will process 'LANDSAT/LC09/C02/T1_L2' and download bands ['SR_B2', 'SR_B3', 'SR_B4']
#   Profile 2 will process 'COPERNICUS/S2_SR_HARMONIZED' and download bands ['NDVI']
# ℹ -------------------- Downloading Profile 1 --------------------
# Running preprocess() -----
# ℹ Number of image(s) found: 2
# ⊙ Applying scale, offset and cloud masks... 1.5s
# ⊙ Calculating spectral indices: NDVI... 0.4s
# ✔ Preprocessing complete
# Running download() -----
# ℹ Band(s) selected: ['SR_B2_mean', 'SR_B3_mean', 'SR_B4_mean']
# ℹ Setting scale to ~160.2m, converted from 6.0 arcsec at latitude -30.27
# ℹ Setting download dir to test_temporal/ee
# ⊙ Downloading ee_LANDSAT_f58091fd.tif 4.5s
# ✔ Google Earth Engine download(s) complete
# ℹ -------------------- Downloading Profile 2 --------------------
# Running preprocess() -----
# ℹ Number of image(s) found: 22
# ⊙ Applying scale, offset and cloud masks... 1.5s
# ⊙ Calculating spectral indices: NDVI... 0.3s
# ✔ Preprocessing complete
# Running download() -----
# ℹ Band(s) selected: ['NDVI_mean']
# ℹ Setting scale to ~160.2m, converted from 6.0 arcsec at latitude -30.27
# ℹ Setting download dir to test_temporal/ee
# ⊙ Downloading ee_COPERNICUS_dac18192.tif 4.3s
# ✔ Google Earth Engine download(s) complete
#
# ⌛ Downloading DEA data...
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-01T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-02T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-03T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-04T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-05T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-06T00:00:00.000Z 0.2s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-07T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-08T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-09T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-10T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-11T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-12T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-13T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-14T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-15T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-16T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-17T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-18T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-19T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-20T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-21T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-22T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-23T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-24T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-25T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-26T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-27T00:00:00.000Z 0.2s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-28T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-29T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-30T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-08-31T00:00:00.000Z 0.2s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-01T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-02T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-03T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-04T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-05T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-06T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-07T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-08T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-09T00:00:00.000Z 0.2s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-10T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-11T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-12T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-13T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-14T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-15T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-16T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-17T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-18T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-19T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-20T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-21T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-22T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-23T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-24T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-25T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-26T00:00:00.000Z 0.2s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-27T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-28T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-29T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-09-30T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-10-01T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-10-02T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-10-03T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-10-04T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-10-05T00:00:00.000Z 0.1s
# ⊙ Downloading ga_ls8c_ard_3.tif for 2022-10
# mean of 2022-10-31 saved in: test_temporal/silo/silo_min_temp_2022-08-01-2022-12-01_mean_2022-10-31.tif
#
# Extracting data points for example-site_llara.csv  -----
# ⊙ Extracting values from raster files... (!) 0.7s
# ✔ Data points extracted to test_temporalresults.gpkg
#
# 🎉 🎉 🎉 Harvest complete 🎉 🎉 🎉

# %% [markdown]
# ### Inspect result dataframe

# %%
# Inspect either entire generated dataframe with 
# df
# or only the first rows with
df.head()
# Out:
#     Longitude   Latitude  \
# 0  149.852680 -30.264663
# 1  149.884838 -30.265302
# 2  149.884838 -30.265302
# 3  149.838791 -30.278542
# 4  149.830843 -30.275437
#
#    ee_COPERNICUS_d1229d42_mean_2022-08-01-to-2022-08-31_NDVI_mean  \
# 0                                           0.456572
# 1                                           0.132410
# 2                                           0.132410
# 3                                           0.421019
# 4                                           0.367244
#
#    ee_LANDSAT_2a2b9af2_mean_2022-08-01-to-2022-08-31_SR_B2_mean  \
# 0                                             7964.0
# 1                                             8598.0
# 2                                             8598.0
# 3                                             8055.0
# 4                                             8316.0
#
#    ee_LANDSAT_2a2b9af2_mean_2022-08-01-to-2022-08-31_SR_B3_mean  \
# 0                                             9059.0
# 1                                             9324.0
# 2                                             9324.0
# 3                                             9010.0
# 4                                            10031.0
#
#    ee_LANDSAT_2a2b9af2_mean_2022-08-01-to-2022-08-31_SR_B4_mean  \
# 0                                             8309.0
# 1                                            10031.0
# 2                                            10031.0
# 3                                             8257.0
# 4                                             9594.0
#
#    ee_LANDSAT_71cd5d63_mean_2022-08-31-to-2022-09-30_SR_B2_mean  \
# 0                                             8073.0
# 1                                             8748.0
# 2                                             8748.0
# 3                                             8049.0
# 4                                             8101.0
#
#    ee_LANDSAT_71cd5d63_mean_2022-08-31-to-2022-09-30_SR_B3_mean  \
# 0                                             8772.0
# 1                                             9505.0
# 2                                             9505.0
# 3                                             8750.0
# 4                                             9553.0
#
#    ee_LANDSAT_71cd5d63_mean_2022-08-31-to-2022-09-30_SR_B4_mean  \
# 0                                             8066.0
# 1                                            10193.0
# 2                                            10193.0
# 3                                             8083.0
# 4                                             8658.0
#
#    ee_COPERNICUS_fcb50880_mean_2022-08-31-to-2022-09-30_NDVI_mean  ...  \
# 0                                           0.619215               ...
# 1                                           0.183365               ...
# 2                                           0.183365               ...
# 3                                           0.683723               ...
# 4                                           0.611031               ...
#
#    ga_ls_landcover_level4  \
# 0                    97.0
# 1                    30.0
# 2                    30.0
# 3                    97.0
# 4                    35.0
#
#    silo_max_temp_2022-08-01-2022-12-01_mean_2022-07-31_1  \
# 0                                          19.025805
# 1                                          18.919352
# 2                                          18.919352
# 3                                          19.216133
# 4                                          19.216133
#
#    silo_max_temp_2022-08-01-2022-12-01_mean_2022-08-31_1  \
# 0                                          20.974195
# 1                                          20.887094
# 2                                          20.887094
# 3                                          21.154839
# 4                                          21.154839
#
#    silo_max_temp_2022-08-01-2022-12-01_mean_2022-10-01_1  \
# 0                                          24.726673
# 1                                          24.623329
# 2                                          24.623329
# 3                                          24.900000
# 4                                          24.900000
#
#    silo_max_temp_2022-08-01-2022-12-01_mean_2022-10-31_1  \
# 0                                          26.345163
# 1                                          26.245161
# 2                                          26.245161
# 3                                          26.496777
# 4                                          26.496777
#
#    silo_min_temp_2022-08-01-2022-12-01_mean_2022-07-31_1  \
# 0                                           5.735485
# 1                                           5.590323
# 2                                           5.590323
# 3                                           5.819355
# 4                                           5.819355
#
#    silo_min_temp_2022-08-01-2022-12-01_mean_2022-08-31_1  \
# 0                                           8.151613
# 1                                           8.032257
# 2                                           8.032257
# 3                                           8.261291
# 4                                           8.261291
#
#    silo_min_temp_2022-08-01-2022-12-01_mean_2022-10-01_1  \
# 0                                          11.923333
# 1                                          11.776666
# 2                                          11.776666
# 3                                          12.003332
# 4                                          12.003332
#
#    silo_min_temp_2022-08-01-2022-12-01_mean_2022-10-31_1  \
# 0                                          11.961290
# 1                                          11.822580
# 2                                          11.822580
# 3                                          12.045162
# 4                                          12.045162
#
#                       geometry
# 0  POINT (149.85268 -30.26466)
# 1  POINT (149.88484 -30.26530)
# 2  POINT (149.88484 -30.26530)
# 3  POINT (149.83879 -30.27854)
# 4  POINT (149.83084 -30.27544)
#
# [5 rows x 65 columns]

# %%
print('Number of columns in dataframe: ', len(df.columns))
# Print column names of dataframe
print(df.columns)
# Out:
# Number of columns in dataframe:  65
# Index(['Longitude', 'Latitude',
#        'ee_COPERNICUS_d1229d42_mean_2022-08-01-to-2022-08-31_NDVI_mean',
#        'ee_LANDSAT_2a2b9af2_mean_2022-08-01-to-2022-08-31_SR_B2_mean',
#        'ee_LANDSAT_2a2b9af2_mean_2022-08-01-to-2022-08-31_SR_B3_mean',
#        'ee_LANDSAT_2a2b9af2_mean_2022-08-01-to-2022-08-31_SR_B4_mean',
#        'ee_LANDSAT_71cd5d63_mean_2022-08-31-to-2022-09-30_SR_B2_mean',
#        'ee_LANDSAT_71cd5d63_mean_2022-08-31-to-2022-09-30_SR_B3_mean',
#        'ee_LANDSAT_71cd5d63_mean_2022-08-31-to-2022-09-30_SR_B4_mean',
#        'ee_COPERNICUS_fcb50880_mean_2022-08-31-to-2022-09-30_NDVI_mean',
#        'ee_LANDSAT_6b57e1a5_mean_2022-09-30-to-2022-10-30_SR_B2_mean',
#        'ee_LANDSAT_6b57e1a5_mean_2022-09-30-to-2022-10-30_SR_B3_mean',
#        'ee_LANDSAT_6b57e1a5_mean_2022-09-30-to-2022-10-30_SR_B4_mean',
#        'ee_COPERNICUS_03b3ab57_mean_2022-09-30-to-2022-10-30_NDVI_mean',
#        'ee_COPERNICUS_dac18192_mean_2022-10-30-to-2022-11-29_NDVI_mean',
#        'ee_LANDSAT_f58091fd_mean_2022-10-30-to-2022-11-29_SR_B2_mean',
#        'ee_LANDSAT_f58091fd_mean_2022-10-30-to-2022-11-29_SR_B3_mean',
#        'ee_LANDSAT_f58091fd_mean_2022-10-30-to-2022-11-29_SR_B4_mean',
#        'DEA_ga_ls8c_ard_3_median_2022-07-30_nbart_blue',
#        'DEA_ga_ls8c_ard_3_median_2022-07-30_nbart_green',
#        'DEA_ga_ls8c_ard_3_median_2022-07-30_nbart_red',
#        'DEA_ga_ls8c_ard_3_median_2022-07-30_nbart_nir',
#        'DEA_ga_ls8c_ard_3_median_2022-07-30_nbart_swir_1',
#        'DEA_ga_ls8c_ard_3_median_2022-07-30_nbart_swir_2',
#        'DEA_ga_ls8c_ard_3_median_2022-07-30_oa_fmask',
#        'DEA_ga_ls8c_ard_3_median_2022-07-30_nbart_panchromatic',
#        'DEA_ga_ls8c_ard_3_median_2022-07-30_coastal_aerosol',
#        'DEA_ga_ls8c_ard_3_median_2022-08-30_nbart_blue',
#        'DEA_ga_ls8c_ard_3_median_2022-08-30_nbart_green',
#        'DEA_ga_ls8c_ard_3_median_2022-08-30_nbart_red',
#        'DEA_ga_ls8c_ard_3_median_2022-08-30_nbart_nir',
#        'DEA_ga_ls8c_ard_3_median_2022-08-30_nbart_swir_1',
#        'DEA_ga_ls8c_ard_3_median_2022-08-30_nbart_swir_2',
#        'DEA_ga_ls8c_ard_3_median_2022-08-30_oa_fmask',
#        'DEA_ga_ls8c_ard_3_median_2022-08-30_nbart_panchromatic',
#        'DEA_ga_ls8c_ard_3_median_2022-08-30_coastal_aerosol',
#        'DEA_ga_ls8c_ard_3_median_2022-09-30_nbart_blue',
#        'DEA_ga_ls8c_ard_3_median_2022-09-30_nbart_green',
#        'DEA_ga_ls8c_ard_3_median_2022-09-30_nbart_red',
#        'DEA_ga_ls8c_ard_3_median_2022-09-30_nbart_nir',
#        'DEA_ga_ls8c_ard_3_median_2022-09-30_nbart_swir_1',
#        'DEA_ga_ls8c_ard_3_median_2022-09-30_nbart_swir_2',
#        'DEA_ga_ls8c_ard_3_median_2022-09-30_oa_fmask',
#        'DEA_ga_ls8c_ard_3_median_2022-09-30_nbart_panchromatic',
#        'DEA_ga_ls8c_ard_3_median_2022-09-30_coastal_aerosol',
#        'DEA_ga_ls8c_ard_3_median_2022-10-30_nbart_blue',
#        'DEA_ga_ls8c_ard_3_median_2022-10-30_nbart_green',
#        'DEA_ga_ls8c_ard_3_median_2022-10-30_nbart_red',
#        'DEA_ga_ls8c_ard_3_median_2022-10-30_nbart_nir',
#        'DEA_ga_ls8c_ard_3_median_2022-10-30_nbart_swir_1',
#        'DEA_ga_ls8c_ard_3_median_2022-10-30_nbart_swir_2',
#        'DEA_ga_ls8c_ard_3_median_2022-10-30_oa_fmask',
#        'DEA_ga_ls8c_ard_3_median_2022-10-30_nbart_panchromatic',
#        'DEA_ga_ls8c_ard_3_median_2022-10-30_coastal_aerosol',
#        'ga_ls_landcover_level3', 'ga_ls_landcover_level4',
#        'silo_max_temp_2022-08-01-2022-12-01_mean_2022-07-31_1',
#        'silo_max_temp_2022-08-01-2022-12-01_mean_2022-08-31_1',
#        'silo_max_temp_2022-08-01-2022-12-01_mean_2022-10-01_1',
#        'silo_max_temp_2022-08-01-2022-12-01_mean_2022-10-31_1',
#        'silo_min_temp_2022-08-01-2022-12-01_mean_2022-07-31_1',
#        'silo_min_temp_2022-08-01-2022-12-01_mean_2022-08-31_1',
#        'silo_min_temp_2022-08-01-2022-12-01_mean_2022-10-01_1',
#        'silo_min_temp_2022-08-01-2022-12-01_mean_2022-10-31_1', 'geometry'],
#       dtype='object')
