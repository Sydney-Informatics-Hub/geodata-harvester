# %% [markdown]
# # Session 1 - running a harvest with a settings.yaml file
# -------------------------
#
# The Data Harvester enables researchers with reusable workflows for automatic data extraction from a range of data sources. User provided data is auto-completed with a suitable set of spatial- and temporal-aligned covariates as a ready-made dataset for machine learning and agriculture models. In addition, all requested data layer maps are automatically extracted and aligned for a specific region and time period.
#
# This session introduces you to the `geodata_harvester` package by showing you how to download files with minimal code input, which is achieved by running the `harvest.run()` function.
#
# Let's test this out. Run the following code block:

# %%
from geodata_harvester import harvest

df = harvest.run("settings/settings_session1.yaml", preview=True, return_df=True)
# Out:
# Starting the data harvester -----
# ℹ Found the following 6 sources: ['DEA', 'DEM', 'Landscape', 'Radiometric', 'SILO', 'SLGA']
#
# Downloading from API sources -----
#
# ⌛ Downloading DEA data...
# ⊙ Downloading landsat_barest_earth.tif for None 1.0s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-01T00:00:00.000Z 1.1s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-02T00:00:00.000Z 1.0s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-03T00:00:00.000Z 0.9s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-04T00:00:00.000Z 2.9s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-05T00:00:00.000Z 3.1s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-06T00:00:00.000Z 1.1s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-07T00:00:00.000Z 1.2s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-08T00:00:00.000Z 2.0s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-09T00:00:00.000Z 1.4s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-10T00:00:00.000Z 1.4s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-11T00:00:00.000Z 1.3s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-12T00:00:00.000Z 3.0s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-13T00:00:00.000Z 1.1s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-14T00:00:00.000Z 1.1s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-15T00:00:00.000Z 1.0s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-16T00:00:00.000Z 1.1s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-17T00:00:00.000Z 1.1s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-18T00:00:00.000Z 1.2s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-19T00:00:00.000Z 1.3s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-20T00:00:00.000Z 1.3s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-21T00:00:00.000Z 3.4s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-22T00:00:00.000Z 2.0s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-23T00:00:00.000Z 1.8s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-24T00:00:00.000Z 0.9s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-25T00:00:00.000Z 1.1s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-26T00:00:00.000Z 1.2s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-27T00:00:00.000Z 1.0s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-28T00:00:00.000Z 3.0s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-29T00:00:00.000Z 0.9s
# ⊙ Downloading ga_ls_ard_3.tif for 2022-10-30T00:00:00.000Z 1.0s
#
# ⌛ Downloading DEM data...
# ⊙ Retrieving coverage from WCS server 0.7s
# ⊙ Downloading DEM_SRTM_1_Second_Hydro_Enforced_2023_01_23.tif 2.6s
#
# ⌛ Downloading Landscape data...
# ⊙ Downloading Landscape_Slope.tif 0.8s
# ⊙ Downloading Landscape_Aspect.tif 0.6s
# ⊙ Downloading Landscape_Relief_300m.tif 0.7s
#
# ⌛ Downloading Radiometric data...
# ⊙ Downloading radmap2019_grid_dose_terr_awags_rad_2019 2.5s
# ⊙ Downloading radmap2019_grid_dose_terr_filtered_awags_rad_2019 2.5s
#
# ⌛ Downloading SILO data...
# ⊙ Downloading daily_rain for 2022 31.4s
# ⊙ Downloading max_temp for 2022 30.8s
# ⊙ Downloading min_temp for 2022 30.1s
# ⊙ Downloading monthly_rain for 2022 2.5s
# Layer name processing not valid. Choose from: dict_keys(['daily_rain', 'monthly_rain', 'max_temp', 'min_temp', 'vp', 'vp_deficit', 'evap_pan', 'evap_syn', 'evap_comb', 'evap_morton_lake', 'radiation', 'rh_tmax', 'rh_tmin', 'et_short_crop', 'et_tall_crop', 'et_morton_actual', 'et_morton_potential', 'et_morton_wet', 'mslp'])
# Error: Number of filenames does not match number of layernames. Dataframe not updated.
#
# ⌛ Downloading SLGA data...
# ⊙ Downloading SLGA_Bulk_Density_0-5cm.tif 10.0s
# ⊙ Downloading SLGA_Bulk_Density_0-5cm_5percentile.tif 0.8s
# ⊙ Downloading SLGA_Bulk_Density_0-5cm_95percentile.tif 6.6s
# ⊙ Downloading SLGA_Clay_0-5cm.tif 10.7s
# ⊙ Downloading SLGA_Clay_0-5cm_5percentile.tif 5.5s
# ⊙ Downloading SLGA_Clay_0-5cm_95percentile.tif 0.7s
#
# Extracting data points for example-site_llara.csv  -----
# ⊙ • landsat_barest_earth | pixel size: (77, 107) 0.5s
# ⊙ • ga_ls_ard_3_2022-9-30 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-1 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-2 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-3 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-4 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-5 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-6 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-7 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-8 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-9 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-10 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-11 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-12 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-13 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-14 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-15 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-16 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-17 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-18 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-19 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-20 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-21 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-22 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-23 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-24 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-25 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-26 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-27 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-28 | pixel size: (77, 107) 0.0s
# ⊙ • ga_ls_ard_3_2022-10-29 | pixel size: (77, 107) 0.0s
# ⊙ • DEM_SRTM_1_Second_Hydro_Enforced_2023_01_23 | pixel size: (78, 108) 0.0s
# ⊙ • Landscape_Slope | pixel size: (78, 108) 0.0s
# ⊙ • Landscape_Aspect | pixel size: (78, 108) 0.0s
# ⊙ • Landscape_Relief_300m | pixel size: (78, 108) 0.0s
# ⊙ • radiometric_radmap2019_grid_dose_terr_awags_rad_2019 | pixel size: (466, 647) 0.0s
# ⊙ • radiometric_radmap2019_grid_dose_terr_filtered_awags_rad_2019 | pixel size: (466, 647) 0.0s
# ⊙ • SLGA_Bulk_Density_0-5cm | pixel size: (156, 216) 0.0s
# ⊙ • SLGA_Clay_0-5cm | pixel size: (156, 216) 0.0s
# ✔ Data points extracted to results/results.gpkg
# 🎉 🎉 🎉 Harvest complete 🎉 🎉 🎉

# %% [markdown]
# ## Done!
#
# Congratulations you have just downloaded data from several sources and defined a consistent dataset over an area of interest ready for further analysis!
#
# Now let's look at what we did in the [**Next Session**](/pydocs/p20-advanced)
